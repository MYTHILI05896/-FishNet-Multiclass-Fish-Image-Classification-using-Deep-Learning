# %%
# 1. Import Libraries
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# 2. Define Paths & Constants
DATA_DIR = "../data/images.cv_jzk6llhf18tm3k0kyttxz/data"
TRAIN_DIR = os.path.join(DATA_DIR, "train")
TEST_DIR = os.path.join(DATA_DIR, "test")
IMG_SIZE = (224, 224)
BATCH_SIZE = 16

# 3. Data Generators
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# 4. Build Transfer Learning Model (VGG16)
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
for layer in base_model.layers:
    layer.trainable = False

x = base_model.output
x = Flatten()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.3)(x)
output = Dense(train_generator.num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

# 5. Compile Model
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# 6. Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
checkpoint = ModelCheckpoint("vgg16_best_model.h5", monitor='val_accuracy', save_best_only=True)

# 7. Train Model
EPOCHS = 10
history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=test_generator,
    callbacks=[early_stop, checkpoint]
)

# 8. Plot Training History
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 2025-08-06 03:05:55.833569: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-08-06 03:05:56.103002: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-08-06 03:05:56.209900: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754449556.546672    2112 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754449556.628507    2112 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1754449560.158806    2112 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1754449560.158838    2112 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1754449560.158841    2112 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1754449560.158843    2112 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-06 03:06:00.441126: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Found 6225 images belonging to 11 classes.
# Found 3187 images belonging to 11 classes.
# 2025-08-06 03:06:18.709245: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2025-08-06 03:06:22.916348: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 25690112 exceeds 10% of free system memory.
# 2025-08-06 03:06:22.947705: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 25690112 exceeds 10% of free system memory.
# 2025-08-06 03:06:22.960566: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 25690112 exceeds 10% of free system memory.
# /usr/local/python/3.12.1/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 2025-08-06 03:06:25.183705: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 25690112 exceeds 10% of free system memory.
# 2025-08-06 03:06:25.231799: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 25690112 exceeds 10% of free system memory.
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.6396 - loss: 1.1256
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 3348s 9s/step - accuracy: 0.8056 - loss: 0.6582 - val_accuracy: 0.9617 - val_loss: 0.1800
# Epoch 2/10
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.9618 - loss: 0.1728
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 3342s 9s/step - accuracy: 0.9701 - loss: 0.1444 - val_accuracy: 0.9840 - val_loss: 0.0882
# Epoch 3/10
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.9875 - loss: 0.0747
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 3372s 9s/step - accuracy: 0.9859 - loss: 0.0749 - val_accuracy: 0.9859 - val_loss: 0.0655
# Epoch 4/10
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.9932 - loss: 0.0461
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 3330s 9s/step - accuracy: 0.9913 - loss: 0.0491 - val_accuracy: 0.9912 - val_loss: 0.0469
# Epoch 5/10
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 3329s 9s/step - accuracy: 0.9974 - loss: 0.0256 - val_accuracy: 0.9909 - val_loss: 0.0422
# Epoch 6/10
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 3339s 9s/step - accuracy: 0.9992 - loss: 0.0172 - val_accuracy: 0.9884 - val_loss: 0.0421
# Epoch 7/10
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.9990 - loss: 0.0150
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 3334s 9s/step - accuracy: 0.9986 - loss: 0.0155 - val_accuracy: 0.9937 - val_loss: 0.0276
# Epoch 8/10
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 3335s 9s/step - accuracy: 0.9989 - loss: 0.0101 - val_accuracy: 0.9922 - val_loss: 0.0313
# Epoch 9/10
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 3341s 9s/step - accuracy: 0.9994 - loss: 0.0081 - val_accuracy: 0.9928 - val_loss: 0.0254
# Epoch 10/10
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 3376s 9s/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.9925 - val_loss: 0.0278
